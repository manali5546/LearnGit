# %%
import pandas as pd

# %%
df = pd.read_json('http://127.0.0.1:8000/api/pythonclass/details/')

# %%
df
# Out:
#    id     name  age              email      mobile
# 0   1  Gajanan   25  gajanan@gmail.com  4649499949
# 1   2   naresh   35     test@gmail.com    98595959
# 2   3      dgd   34     test@gmail.com  8329370756
# 3   4   Sonali   32      snl@gmail.com  4461995959

# %%
import requests

# %%
requests.post('http:/127.0.0.1:8000/api/pythonclass/details/',data= {'id':'6','name':'test1','age':35,'email':'test@yahoo.com','mobile':2616616})
# Out:
# <Response [201]>

# %%
requests.delete('http://127.0.0.1:8000/api/pythonclass/detailsupdatedelete/2')
# Out:
# <Response [204]>

# %%
df
# Out:
#    id     name  age              email      mobile
# 0   1  Gajanan   25  gajanan@gmail.com  4649499949
# 1   2   naresh   35     test@gmail.com    98595959
# 2   3      dgd   34     test@gmail.com  8329370756
# 3   4   Sonali   32      snl@gmail.com  4461995959

# %%
df
# Out:
#    id     name  age              email      mobile
# 0   1  Gajanan   25  gajanan@gmail.com  4649499949
# 1   2   naresh   35     test@gmail.com    98595959
# 2   3      dgd   34     test@gmail.com  8329370756
# 3   4   Sonali   32      snl@gmail.com  4461995959

# %%
#new col add

# %%
df['new col '] = 'test'

# %%
df
# Out:
#    id     name  age              email      mobile new col
# 0   1  Gajanan   25  gajanan@gmail.com  4649499949     test
# 1   2   naresh   35     test@gmail.com    98595959     test
# 2   3      dgd   34     test@gmail.com  8329370756     test
# 3   4   Sonali   32      snl@gmail.com  4461995959     test

# %%
import datetime
df['last_updated'] = datetime.datetime.now()

# %%
df
# Out:
#    id     name  age              email      mobile new col   \
# 0   1  Gajanan   25  gajanan@gmail.com  4649499949     test
# 1   2   naresh   35     test@gmail.com    98595959     test
# 2   3      dgd   34     test@gmail.com  8329370756     test
# 3   4   Sonali   32      snl@gmail.com  4461995959     test
#
#                 last_updated
# 0 2023-02-21 20:22:20.506973
# 1 2023-02-21 20:22:20.506973
# 2 2023-02-21 20:22:20.506973
# 3 2023-02-21 20:22:20.506973

# %%
df['course'] = 'Python'

# %%
df
# Out:
#    id     name  age              email      mobile new col   \
# 0   1  Gajanan   25  gajanan@gmail.com  4649499949     test
# 1   2   naresh   35     test@gmail.com    98595959     test
# 2   3      dgd   34     test@gmail.com  8329370756     test
# 3   4   Sonali   32      snl@gmail.com  4461995959     test
#
#                 last_updated  course
# 0 2023-02-21 20:22:20.506973  Python
# 1 2023-02-21 20:22:20.506973  Python
# 2 2023-02-21 20:22:20.506973  Python
# 3 2023-02-21 20:22:20.506973  Python

# %%
df.iloc[1][7] = 'Java'
# Out:
# C:\Users\kanti\AppData\Local\Temp\ipykernel_11992\1006262005.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[1][7] = 'Java'

# %%
df['']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1 = df[df['id']==1]['course']='Java'
# Out:
# C:\Users\kanti\AppData\Local\Temp\ipykernel_11992\1604633332.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1 = df[df['id']==1]['course']='Java'

# %%
df1
# Out:
# 'Java'

# %%
df.loc[1,'course'] = 'Java'

# %%
df
# Out:
#    id     name  age              email      mobile new col   \
# 0   1  Gajanan   25  gajanan@gmail.com  4649499949     test
# 1   2   naresh   35     test@gmail.com    98595959     test
# 2   3      dgd   34     test@gmail.com  8329370756     test
# 3   4   Sonali   32      snl@gmail.com  4461995959     test
#
#                 last_updated  course
# 0 2023-02-21 20:22:20.506973  Python
# 1 2023-02-21 20:22:20.506973    Java
# 2 2023-02-21 20:22:20.506973  Python
# 3 2023-02-21 20:22:20.506973  Python

# %%
df.iloc[3,7] = 'AWS'

# %%
df
# Out:
#    id     name  age              email      mobile new col   \
# 0   1  Gajanan   25  gajanan@gmail.com  4649499949     test
# 1   2   naresh   35     test@gmail.com    98595959     test
# 2   3      dgd   34     test@gmail.com  8329370756     test
# 3   4   Sonali   32      snl@gmail.com  4461995959     test
#
#                 last_updated  course
# 0 2023-02-21 20:22:20.506973  Python
# 1 2023-02-21 20:22:20.506973    Java
# 2 2023-02-21 20:22:20.506973  Python
# 3 2023-02-21 20:22:20.506973     AWS

# %%
#drop col from df

# %%
df
# Out:
#    id     name  age              email      mobile new col   \
# 0   1  Gajanan   25  gajanan@gmail.com  4649499949     test
# 1   2   naresh   35     test@gmail.com    98595959     test
# 2   3      dgd   34     test@gmail.com  8329370756     test
# 3   4   Sonali   32      snl@gmail.com  4461995959     test
#
#                 last_updated  course
# 0 2023-02-21 20:22:20.506973  Python
# 1 2023-02-21 20:22:20.506973    Java
# 2 2023-02-21 20:22:20.506973  Python
# 3 2023-02-21 20:22:20.506973     AWS

# %%
df3 = df.drop('new col ',axis=1)

# %%
df3
# Out:
#    id     name  age              email      mobile               last_updated  \
# 0   1  Gajanan   25  gajanan@gmail.com  4649499949 2023-02-21 20:22:20.506973
# 1   2   naresh   35     test@gmail.com    98595959 2023-02-21 20:22:20.506973
# 2   3      dgd   34     test@gmail.com  8329370756 2023-02-21 20:22:20.506973
# 3   4   Sonali   32      snl@gmail.com  4461995959 2023-02-21 20:22:20.506973
#
#    course
# 0  Python
# 1    Java
# 2  Python
# 3     AWS

# %%
df.drop('email',axis=1,inplace=True)

# %%
df
# Out:
#    id     name  age      mobile new col                last_updated  course
# 0   1  Gajanan   25  4649499949     test 2023-02-21 20:22:20.506973  Python
# 1   2   naresh   35    98595959     test 2023-02-21 20:22:20.506973    Java
# 2   3      dgd   34  8329370756     test 2023-02-21 20:22:20.506973  Python
# 3   4   Sonali   32  4461995959     test 2023-02-21 20:22:20.506973     AWS

# %%
#note : col only delete from dataframe only.

# %%
df
# Out:
#    id     name  age      mobile new col                last_updated  course
# 0   1  Gajanan   25  4649499949     test 2023-02-21 20:22:20.506973  Python
# 1   2   naresh   35    98595959     test 2023-02-21 20:22:20.506973    Java
# 2   3      dgd   34  8329370756     test 2023-02-21 20:22:20.506973  Python
# 3   4   Sonali   32  4461995959     test 2023-02-21 20:22:20.506973     AWS

# %%
df.drop(columns=['id','name','mobile'],axis=1,inplace=True)

# %%
df
# Out:
#    age new col                last_updated  course
# 0   25     test 2023-02-21 20:22:20.506973  Python
# 1   35     test 2023-02-21 20:22:20.506973    Java
# 2   34     test 2023-02-21 20:22:20.506973  Python
# 3   32     test 2023-02-21 20:22:20.506973     AWS

# %%
df.drop('course',axis=1)
# Out:
#    age new col                last_updated
# 0   25     test 2023-02-21 20:22:20.506973
# 1   35     test 2023-02-21 20:22:20.506973
# 2   34     test 2023-02-21 20:22:20.506973
# 3   32     test 2023-02-21 20:22:20.506973

# %%
df
# Out:
#    age new col                last_updated  course
# 0   25     test 2023-02-21 20:22:20.506973  Python
# 1   35     test 2023-02-21 20:22:20.506973    Java
# 2   34     test 2023-02-21 20:22:20.506973  Python
# 3   32     test 2023-02-21 20:22:20.506973     AWS

# %%
#del rows

# %%
df.drop(1,inplace=True)

# %%
df
# Out:
#    age new col                last_updated  course
# 0   25     test 2023-02-21 20:22:20.506973  Python
# 2   34     test 2023-02-21 20:22:20.506973  Python
# 3   32     test 2023-02-21 20:22:20.506973     AWS

# %%
df1 = pd.read_excel('Data_final_pivot_table.xlsx')

# %%
df1.drop(list(range(2000)))
# Out:
#       Client_Code                    Client_Name  \
# 2000     57210262          Prime-Tech  Computers
# 2001     57210264      Systech Infocom Computers
# 2002     57210265            Chaitanya Computers
# 2003     57210271             Creative Computers
# 2004     57210273          VENUS COMPUTERS,GHOTI
# ...           ...                            ...
# 3297     42210125              Jalaram Computers
# 3298     42210126                  sai computers
# 3299     42210127  Good-Luck Computers, Maregaon
# 3300     42210128      SUYASH COMPUTER INSTITUTE
# 3301     42210132       IMAGE COMPUTER EDUCATION
#
#                                                 Address      City    Taluka  \
# 2000  SHOP NO.11& 3 DREAM SANKUL & RAJ LAXMI  APPT.,...    Nashik    Nashik
# 2001  N-10, M-1/10/4, Maharana Pratap Chowk, New Cid...    Nashik    Nashik
# 2002  Chaitnya Computer ,Shivanjali Nager,Opp-RTO,Pe...    Nashik    Nashik
# ...

# %%
df1
# Out:
#       Client_Code                           Client_Name  \
# 0        19210001     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
df1
# Out:
#       Client_Code                           Client_Name  \
# 0        19210001     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
df['temp'] = 45

# %%
df
# Out:
#    age new col                last_updated  course  temp
# 0   25     test 2023-02-21 20:22:20.506973  Python    45
# 2   34     test 2023-02-21 20:22:20.506973  Python    45
# 3   32     test 2023-02-21 20:22:20.506973     AWS    45

# %%
df['add'] = df['age'] + df['temp']

# %%
df
# Out:
#    age new col                last_updated  course  temp  add
# 0   25     test 2023-02-21 20:22:20.506973  Python    45   70
# 2   34     test 2023-02-21 20:22:20.506973  Python    45   79
# 3   32     test 2023-02-21 20:22:20.506973     AWS    45   77

# %%
df['concat'] = df['new col '] + df['course']

# %%
df
# Out:
#    age new col                last_updated  course  temp  add      concat
# 0   25     test 2023-02-21 20:22:20.506973  Python    45   70  testPython
# 2   34     test 2023-02-21 20:22:20.506973  Python    45   79  testPython
# 3   32     test 2023-02-21 20:22:20.506973     AWS    45   77     testAWS

# %%
df['len_course'] =df['course']

# %%
df
# Out:
#    age new col                last_updated  course  temp  add      concat  \
# 0   25     test 2023-02-21 20:22:20.506973  Python    45   70  testPython
# 2   34     test 2023-02-21 20:22:20.506973  Python    45   79  testPython
# 3   32     test 2023-02-21 20:22:20.506973     AWS    45   77     testAWS
#
#    len_course
# 0           3
# 2           3
# 3           3

# %%
len(df['course'])
# Out:
# 3

# %%
df1['District'].unique()
# Out:
# array(['Raigad', 'Ratnagiri', 'Sindhudurg', 'Hingoli', 'Latur', 'Nanded',
#        'Parbhani', 'Aurangabad', 'Beed', 'Jalna', 'Osmanabad',
#        'Mumbai City', 'Mumbai Eastern Suburbs', 'Mumbai Harbour Suburbs',
#        'Mumbai Western Suburbs', 'Palghar', 'Thane', 'Dhule', 'Jalgaon',
#        'Nandurbar', 'Ahmednagar', 'Nashik', 'Pune North', 'Pune South',
#        'Solapur', 'Kolhapur', 'Sangli', 'Satara', 'Bhandara',
#        'Chandrapur', 'Gadchiroli', 'Gondiya', 'Nagpur', 'Wardha', 'Akola',
#        'Amravati', 'Buldhana', 'Washim', 'Yavatmal'], dtype=object)

# %%
df1['District'].value_counts(ascending=True)
# Out:
# Nandurbar                  15
# Gadchiroli                 20
# Bhandara                   28
# Gondiya                    31
# Washim                     33
# Wardha                     37
# Dhule                      37
# Palghar                    38
# Hingoli                    42
# Akola                      46
# Mumbai Harbour Suburbs     47
# Chandrapur                 55
# Mumbai Eastern Suburbs     59
# Yavatmal                   63
# Sindhudurg                 67
# Buldhana                   69
# Parbhani                   69
# Amravati                   76
# Ratnagiri                  82
# Mumbai City                83
# Sangli                     85
# Osmanabad                  85
# Jalna                      88
# Jalgaon                    88
# Solapur                    89
# Satara                     98
# Pune South                101
# Mumbai Western Suburbs    106
# Latur                     111
# Ahmednagar                119
# Kolhapur                  124
# ...

# %%
df1
# Out:
#       Client_Code                           Client_Name  \
# 0        19210001     Essay Infotech Computer Institute
# 1        19210002  Mark Computer Information Technology
# 2        19210004         Sharmeen`S Computer Education
# 3        19210007                          Om Computers
# 4        19210010                     Webtech Computers
# ...           ...                                   ...
# 3297     42210125                     Jalaram Computers
# 3298     42210126                         sai computers
# 3299     42210127         Good-Luck Computers, Maregaon
# 3300     42210128             SUYASH COMPUTER INSTITUTE
# 3301     42210132              IMAGE COMPUTER EDUCATION
#
#                                                 Address            City  \
# 0                Angel Arc,Shop No.13,Plot No-23,Sec-8,       Kalamboli
# 1     1/3, Ashiana Complex, Shivaji Road, Near Hotel...           Mahad
# 2             Plot R-14 Shreebaug, No 3, Near Bus Stand          Alibag
# ...

# %%
df
# Out:
#    age new col                last_updated  course  temp  add      concat  \
# 0   25     test 2023-02-21 20:22:20.506973  Python    45   70  testPython
# 2   34     test 2023-02-21 20:22:20.506973  Python    45   79  testPython
# 3   32     test 2023-02-21 20:22:20.506973     AWS    45   77     testAWS
#
#    len_course
# 0           3
# 2           3
# 3           3

# %%
df
# Out:
#    age new col                last_updated  course  temp  add      concat  \
# 0   25     test 2023-02-21 20:22:20.506973  Python    45   70  testPython
# 2   34     test 2023-02-21 20:22:20.506973  Python    45   79  testPython
# 3   32     test 2023-02-21 20:22:20.506973     AWS    45   77     testAWS
#
#    len_course                                   test12
# 0           3                                   Python
# 2           3                                   Python
# 3           3  0    115
# 2    124
# 3    122
# dtype: int64

# %%
df1.sort_values('City')
# Out:
#       Client_Code                    Client_Name  \
# 970      46210304   ASARADEVI COMPUTER INSTITUTE
# 738      16210226           NEW MAITREE INFOTECH
# 375      45210168                 Rohit Infotech
# 763      16210293          SHRI BALAJI COMPUTERS
# 3055     12210111     UTKARSH COMPUTER EDUCATION
# ...           ...                            ...
# 1441     48210141  Sai Ganesh Computer Education
# 1459    108210044               SHAMAL COMPUTERS
# 1461    108210048                PRIME COMPUTERS
# 1483     78210275   Universal Computer Institute
# 1518     78210045                 Royal Infotech
#
#                                                 Address      City    Taluka  \
# 970                                   shivaji chok adas      ADAS      Kaij
# 738    OPP.HARIDAS TEMPLE, BAJAR GALLI, MAIN ROAD, ADUL      ADUL   Paithan
# 375     05, KAI NIVRUTTI REDDY SANKUL, M.G.COLLEGE ROAD  AHMEDPUR  Ahmadpur
# ...

# %%
#filter records

# %%
df1[(df1['District']=='Aurangabad') | (df1['District']=='Thane') & (df1['Taluka']=='Kannad') ]
# Out:
#      Client_Code                   Client_Name  \
# 638     16210001       Shree Adinath Computers
# 639     16210002           Sarvadnya Computers
# 640     16210003              Atharv Computers
# 641     16210007  Gurukrupa Computer Institute
# 642     16210008       Biit Computer Education
# ..           ...                           ...
# 852     16210500               yugan computers
# 853     16210502  Shree Sai Computers Golegaon
# 854     16210503    ADITICOMPUTERS18@GMAIL.COM
# 855     16210505               DISHA COMPUTERS
# 856     16210510             Shreeram Infotech
#
#                                                Address  \
# 638  PISHOR NAKA, NEAR TIRUPATI HOSPITAL ,CHALISGAO...
# 639  Plot No. 16, NS-1, F-Sector, Ashta Vinayak Mar...
# 640  Opp.Saptapadi hall,Near Baliram patil h.school...
# 641  BEHIND MAHARASHTRA GRAMIN BANK GANESH CHOWK NU...
# 642  Opp. Wani Mangal karayalay (Galli) Shriram Col...
# ..                                                 ...
# ...

# %%
df2 = pd.read_csv('city_temperature.csv')
# Out:
# C:\Users\kanti\AppData\Local\Temp\ipykernel_11992\1406971949.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('city_temperature.csv')

# %%
df2
# Out:
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2906322  North America       US  Additional Territories  San Juan Puerto Rico
# 2906323  North America       US  Additional Territories  San Juan Puerto Rico
# 2906324  North America       US  Additional Territories  San Juan Puerto Rico
# 2906325  North America       US  Additional Territories  San Juan Puerto Rico
# 2906326  North America       US  Additional Territories  San Juan Puerto Rico
#
# ...

# %%
df2['AvgTemperature'].max()
# Out:
# 110.0

# %%
df2['AvgTemperature'].min()
# Out:
# -99.0

# %%
df2['AvgTemperature'].std()
# Out:
# 32.12359394722664

# %%
df2['AvgTemperature'].median()
# Out:
# 62.5

# %%
df2[df2['AvgTemperature']==110.0][['Region','City']]

# %%
x = df2[df2['Year']== df2[df2['AvgTemperature']==df2['AvgTemperature'].min()][['Country','City','AvgTemperature','Year']]['Year'].min()]

# %%
df2['Year'].min()
# Out:
# 200

# %%
df2['Year'] = df2['Year'].apply(lambda x :  str(2000) if x==str(200) else str(x))

# %%
df2['Year'].min()
# Out:
# '1995'

# %%
x['Year'].unique()
# Out:
# array(['1995'], dtype=object)

# %%
x
# Out:
#                 Region  Country                   State                  City  \
# 0               Africa  Algeria                     NaN               Algiers
# 1               Africa  Algeria                     NaN               Algiers
# 2               Africa  Algeria                     NaN               Algiers
# 3               Africa  Algeria                     NaN               Algiers
# 4               Africa  Algeria                     NaN               Algiers
# ...                ...      ...                     ...                   ...
# 2899900  North America       US  Additional Territories  San Juan Puerto Rico
# 2899901  North America       US  Additional Territories  San Juan Puerto Rico
# 2899902  North America       US  Additional Territories  San Juan Puerto Rico
# 2899903  North America       US  Additional Territories  San Juan Puerto Rico
# 2899904  North America       US  Additional Territories  San Juan Puerto Rico
#
# ...

# %%
import pandas as pd

# %%
import requests

# %%
data =  requests.get('https://api.cricapi.com/v1/cricScore?apikey=b717b4dd-f81a-4ca6-9161-186dc9a47cca')

# %%
pd.DataFrame(data.json()['data'])
# Out:
#                                       id          dateTimeGMT matchType  \
# 0   b7151f69-f493-4ba8-ab83-8062a2f27b87  2023-02-28T08:00:00      test
# 1   7e063b2f-b0ce-408e-83c5-5a118d236588  2023-02-27T13:30:00       t20
# 2   cb385a63-2246-4a77-876f-6c5d968c346b  2023-02-26T13:30:00       t20
# 3   c45b4aad-a8a0-47f5-bfd8-a71af9638b12  2023-02-26T12:45:00       t20
# 4   a8396266-4ae6-420e-bde5-e99ae987eceb  2023-02-26T08:30:00       t20
# ..                                   ...                  ...       ...
# 67  bb91a325-eb44-411f-ba99-4fe48c908320  2023-02-15T12:30:00       t20
# 68  77ec1b06-5484-45ed-b90f-8b1a6e10d25e  2023-02-15T04:30:00       odi
# 69  52c38184-de97-4a20-a210-380629564c02  2023-02-15T03:15:00       odi
# 70  9a909c1c-6937-424a-84ca-de5c1c64b2d4  2023-02-15T03:05:00       odi
# 71  23e4156d-8309-4573-8ad1-7a0d35c92903  2023-02-14T17:00:00       t20
#
#                              status       ms                      t1  \
# ...

# %%
data.json()['data']
# Out:
# [{'id': 'b7151f69-f493-4ba8-ab83-8062a2f27b87',
#   'dateTimeGMT': '2023-02-28T08:00:00',
#   'matchType': 'test',
#   'status': 'Match not started',
#   'ms': 'fixture',
#   't1': 'South Africa [RSA]',
#   't2': 'West Indies [WI]',
#   't1s': '',
#   't2s': '',
#   't1img': 'https://g.cricapi.com/img/teams/82-637877071839088912.webp',
#   't2img': 'https://g.cricapi.com/img/teams/100-637877077978319234.webp'},
#  {'id': '7e063b2f-b0ce-408e-83c5-5a118d236588',
#   'dateTimeGMT': '2023-02-27T13:30:00',
#   'matchType': 't20',
#   'status': 'Match not started',
#   'ms': 'fixture',
#   't1': 'Islamabad United [ISU]',
#   't2': 'Lahore Qalandars [LHQ]',
#   't1s': '',
#   't2s': '',
#   't1img': 'https://g.cricapi.com/img/teams/34-637992689284766336.webp',
#   't2img': 'https://g.cricapi.com/img/teams/41-637991979136379824.webp'},
#  {'id': 'cb385a63-2246-4a77-876f-6c5d968c346b',
#   'dateTimeGMT': '2023-02-26T13:30:00',
#   'matchType': 't20',
#   'status': 'Match not started',
# ...

# %%
d =
